# %%
import pandas as pd

df = pd.read_csv("transactions_data.csv")

df.head()
# Out:
#    step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   186  CASH_OUT   117091.39  C1315859721            0.0             0.0
# 1   525   PAYMENT    34864.03   C780882811            0.0             0.0
# 2   355  TRANSFER  1250291.27   C826232127            0.0             0.0
# 3   379  CASH_OUT    28417.85  C1420196705            0.0             0.0
# 4   129   PAYMENT    12917.44  C1295908486            0.0             0.0
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0   C252457797       218270.10       335361.49        0               0
# 1  M1452371331            0.00            0.00        0               0
# 2  C1878065792      1946249.85      3253842.43        0               0
# 3   C112087340        43908.57        72326.42        0               0
# 4   M616054252            0.00            0.00        0               0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   step            5000 non-null   int64
#  1   type            5000 non-null   object
#  2   amount          5000 non-null   float64
#  3   nameOrig        5000 non-null   object
#  4   oldbalanceOrg   5000 non-null   float64
#  5   newbalanceOrig  5000 non-null   float64
#  6   nameDest        5000 non-null   object
#  7   oldbalanceDest  5000 non-null   float64
#  8   newbalanceDest  5000 non-null   float64
#  9   isFraud         5000 non-null   int64
#  10  isFlaggedFraud  5000 non-null   int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 429.8+ KB

# %%
df.describe()
# Out:
#               step        amount  oldbalanceOrg  newbalanceOrig  \
# count  5000.000000  5.000000e+03   5.000000e+03    5.000000e+03
# mean    246.300400  1.842032e+05   8.771686e+05    8.986390e+05
# std     143.016969  4.882534e+05   2.983545e+06    3.019084e+06
# min       1.000000  3.900000e+00   0.000000e+00    0.000000e+00
# 25%     158.000000  1.492347e+04   0.000000e+00    0.000000e+00
# 50%     249.000000  7.821207e+04   1.687914e+04    0.000000e+00
# 75%     347.000000  2.115312e+05   1.135915e+05    1.524894e+05
# max     718.000000  1.270254e+07   3.187613e+07    3.205108e+07
#
#        oldbalanceDest  newbalanceDest      isFraud  isFlaggedFraud
# count    5.000000e+03    5.000000e+03  5000.000000          5000.0
# mean     1.144541e+06    1.282693e+06     0.001200             0.0
# std      4.407009e+06    4.569338e+06     0.034624             0.0
# min      0.000000e+00    0.000000e+00     0.000000             0.0
# 25%      0.000000e+00    0.000000e+00     0.000000             0.0
# 50%      1.459032e+05    2.375174e+05     0.000000             0.0
# 75%      1.020701e+06    1.193954e+06     0.000000             0.0
# max      2.355353e+08    2.358797e+08     1.000000             0.0

# %%
df.describe(include='all')
# Out:
#                step      type        amount     nameOrig  oldbalanceOrg  \
# count   5000.000000      5000  5.000000e+03         5000   5.000000e+03
# unique          NaN         5           NaN         5000            NaN
# top             NaN  CASH_OUT           NaN  C1315859721            NaN
# freq            NaN      1789           NaN            1            NaN
# mean     246.300400       NaN  1.842032e+05          NaN   8.771686e+05
# std      143.016969       NaN  4.882534e+05          NaN   2.983545e+06
# min        1.000000       NaN  3.900000e+00          NaN   0.000000e+00
# 25%      158.000000       NaN  1.492347e+04          NaN   0.000000e+00
# 50%      249.000000       NaN  7.821207e+04          NaN   1.687914e+04
# 75%      347.000000       NaN  2.115312e+05          NaN   1.135915e+05
# max      718.000000       NaN  1.270254e+07          NaN   3.187613e+07
#
#         newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  \
# count     5.000000e+03         5000    5.000000e+03    5.000000e+03
# unique             NaN         4986             NaN             NaN
# top                NaN  C1707392550             NaN             NaN
# freq               NaN            2             NaN             NaN
# mean      8.986390e+05          NaN    1.144541e+06    1.282693e+06
# std       3.019084e+06          NaN    4.407009e+06    4.569338e+06
# min       0.000000e+00          NaN    0.000000e+00    0.000000e+00
# 25%       0.000000e+00          NaN    0.000000e+00    0.000000e+00
# 50%       0.000000e+00          NaN    1.459032e+05    2.375174e+05
# 75%       1.524894e+05          NaN    1.020701e+06    1.193954e+06
# max       3.205108e+07          NaN    2.355353e+08    2.358797e+08
#
#             isFraud  isFlaggedFraud
# count   5000.000000          5000.0
# unique          NaN             NaN
# top             NaN             NaN
# freq            NaN             NaN
# mean       0.001200             0.0
# std        0.034624             0.0
# min        0.000000             0.0
# 25%        0.000000             0.0
# 50%        0.000000             0.0
# 75%        0.000000             0.0
# max        1.000000             0.0

# %%
df.count()
# Out:
# step              5000
# type              5000
# amount            5000
# nameOrig          5000
# oldbalanceOrg     5000
# newbalanceOrig    5000
# nameDest          5000
# oldbalanceDest    5000
# newbalanceDest    5000
# isFraud           5000
# isFlaggedFraud    5000
# dtype: int64

# %%
print("Unique values:", df["isFraud"].unique())
print("\nValue counts:\n", df["isFraud"].value_counts())
# Out:
# Unique values: [0 1]
#
# Value counts:
#  isFraud
# 0    4994
# 1       6
# Name: count, dtype: int64

# %%
df[df['isFraud'] == 1]
# Out:
#       step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 449    699  CASH_OUT   148714.54  C1745419959      148714.54             0.0
# 1053   618  CASH_OUT   114483.78   C934338438      114483.78             0.0
# 2133   563  TRANSFER  2905831.61   C174689091     2905831.61             0.0
# 3080   358  TRANSFER   361877.28   C946052471      361877.28             0.0
# 3111   373  TRANSFER  4294676.05   C975117365     4294676.05             0.0
# 4548   211  CASH_OUT    73599.57  C1559180710       73599.57             0.0
#
#          nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 449   C1737815990            0.00       148714.54        1               0
# 1053   C209796396       780631.49       895115.27        1               0
# 2133   C138574758            0.00            0.00        1               0
# 3080   C621645313            0.00            0.00        1               0
# 3111  C1981314185            0.00            0.00        1               0
# 4548  C1604656634            0.00        73599.57        1               0

# %%
duplicate_rows = df.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %%
print(df.nunique())
# Out:
# step               348
# type                 5
# amount            4996
# nameOrig          5000
# oldbalanceOrg     3332
# newbalanceOrig    2181
# nameDest          4986
# oldbalanceDest    2923
# newbalanceDest    3152
# isFraud              2
# isFlaggedFraud       1
# dtype: int64

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Select only numeric columns for the heatmap
numeric_df = df.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
target_col = "isFraud"

# Loop through non-numeric columns
for col in df.select_dtypes(exclude="number").columns:
    print(f"\n--- Correlation of '{col}' values with {target_col} ---")
    
    # One-hot encode
    encoded = pd.get_dummies(df[col], prefix=col, drop_first=False)
    
    # Correlation with target
    cor_with_target = pd.concat([encoded, df[target_col]], axis=1).corr()[target_col].drop(target_col)

    print(cor_with_target.sort_values(ascending=False))
# Out:
# --- Correlation of 'type' values with isFraud ---
# type_TRANSFER    0.053772
# type_CASH_OUT    0.011073
# type_DEBIT      -0.002952
# type_CASH_IN    -0.019245
# type_PAYMENT    -0.025536
# Name: isFraud, dtype: float64
#
# --- Correlation of 'nameOrig' values with isFraud ---

# %%
df.drop(['isFlaggedFraud'], axis=1, inplace=True)
df.head()
# Out:
#    step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   186  CASH_OUT   117091.39  C1315859721            0.0             0.0
# 1   525   PAYMENT    34864.03   C780882811            0.0             0.0
# 2   355  TRANSFER  1250291.27   C826232127            0.0             0.0
# 3   379  CASH_OUT    28417.85  C1420196705            0.0             0.0
# 4   129   PAYMENT    12917.44  C1295908486            0.0             0.0
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0   C252457797       218270.10       335361.49        0
# 1  M1452371331            0.00            0.00        0
# 2  C1878065792      1946249.85      3253842.43        0
# 3   C112087340        43908.57        72326.42        0
# 4   M616054252            0.00            0.00        0

# %%
for col in df.select_dtypes(include=['float64', 'int64']).columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"Outliers in '{col}': {len(outliers)}")
# Out:
# Outliers in 'step': 72
# Outliers in 'amount': 270
# Outliers in 'oldbalanceOrg': 878
# Outliers in 'newbalanceOrig': 830
# Outliers in 'oldbalanceDest': 597
# Outliers in 'newbalanceDest': 575
# Outliers in 'isFraud': 6

# %%
# Normalize numerical columns using IQR and median, except 'isFraud'
df_normalized = df.copy()
numeric_cols = [col for col in df.select_dtypes(include=['float64', 'int64']).columns if col != 'isFraud']

for col in numeric_cols:
    median = df[col].median()
    iqr = df[col].quantile(0.75) - df[col].quantile(0.25)
    # Avoid division by zero
    if iqr == 0:
        df_normalized[col] = df[col] - median
    else:
        df_normalized[col] = (df[col] - median) / iqr

df_normalized.head()
# Out:
#        step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0 -0.333333  CASH_OUT  0.197751  C1315859721      -0.148595             0.0
# 1  1.460317   PAYMENT -0.220480   C780882811      -0.148595             0.0
# 2  0.560847  TRANSFER  5.961512   C826232127      -0.148595             0.0
# 3  0.687831  CASH_OUT -0.253267  C1420196705      -0.148595             0.0
# 4 -0.634921   PAYMENT -0.332106  C1295908486      -0.148595             0.0
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0   C252457797        0.070899        0.081950        0
# 1  M1452371331       -0.142944       -0.198933        0
# 2  C1878065792        1.763833        2.526332        0
# 3   C112087340       -0.099926       -0.138356        0
# 4   M616054252       -0.142944       -0.198933        0

# %%
from sklearn.preprocessing import LabelEncoder

df_encoded = df_normalized.copy()

for col in df.select_dtypes(exclude="number").columns:
    le = LabelEncoder()
    df_encoded[col] = le.fit_transform(df_encoded[col].astype(str))

# %%
df_encoded
# Out:
#           step  type    amount  nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0    -0.333333     1  0.197751       869      -0.148595        0.000000
# 1     1.460317     3 -0.220480      4470      -0.148595        0.000000
# 2     0.560847     4  5.961512      4587      -0.148595        0.000000
# 3     0.687831     1 -0.253267      1139      -0.148595        0.000000
# 4    -0.634921     3 -0.332106       803      -0.148595        0.000000
# ...        ...   ...       ...       ...            ...             ...
# 4995  0.656085     3 -0.378259      4416      -0.148595        0.000000
# 4996  0.650794     0  0.366664      2149      33.973254       26.403495
# 4997  0.767196     4  6.069538      1428      -0.148595        0.000000
# 4998  0.947090     0 -0.209618      4226      15.020011       11.541946
# 4999 -0.227513     3 -0.367185      3913       0.702260        0.594331
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0         2040        0.070899        0.081950        0
# 1         3723       -0.142944       -0.198933        0
# 2         1536        1.763833        2.526332        0
# 3          224       -0.099926       -0.138356        0
# 4         4633       -0.142944       -0.198933        0
# ...        ...             ...             ...      ...
# 4995      4006       -0.142944       -0.198933        0
# 4996       536        2.278409        1.745175        0
# 4997       422        4.230429        4.604798        0
# 4998      1933        1.281670        0.987967        0
# 4999      4872       -0.142944       -0.198933        0
#
# [5000 rows x 10 columns]
